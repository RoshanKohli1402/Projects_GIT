# %%
import pandas as pd

data_path = 'C:\\Users\\LOQ\\Downloads\\greendestination.csv'
data = pd.read_csv(data_path)

data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
total_employees = data.shape[0]
attrition_count = data[data['Attrition'] == 'Yes'].shape[0]
attrition_rate = (attrition_count / total_employees) * 100
print(f"Attrition Rate: {attrition_rate:.2f}%")
# Out:
# Attrition Rate: 16.12%

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='Age', hue='Attrition', multiple='stack', kde=True)
plt.title('Age Distribution by Attrition')
plt.xlabel('Age')
plt.ylabel('Number of Employees')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='YearsAtCompany', hue='Attrition', multiple='stack', kde=True)
plt.title('Years at Company by Attrition')
plt.xlabel('Years at Company')
plt.ylabel('Number of Employees')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Attrition', y='MonthlyIncome')
plt.title('Monthly Income Distribution by Attrition')
plt.xlabel('Attrition')
plt.ylabel('Monthly Income')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='Attrition', y='Age')
plt.title('Age Distribution by Attrition Status')
plt.xlabel('Attrition')
plt.ylabel('Age')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=data, x='YearsAtCompany', y='Age', hue='Attrition', alpha=0.6)
plt.title('Years at Company vs Age, Colored by Attrition')
plt.xlabel('Years at Company')
plt.ylabel('Age')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=data, x='Attrition', y='MonthlyIncome')
plt.title('Monthly Income Distribution by Attrition')
plt.xlabel('Attrition')
plt.ylabel('Monthly Income')
plt.show()

# %%
plt.figure(figsize=(14, 7))
sns.countplot(data=data, x='Department', hue='Attrition')
plt.title('Attrition by Department')
plt.xlabel('Department')
plt.ylabel('Number of Employees')
plt.show()

plt.figure(figsize=(14, 7))
sns.countplot(data=data, x='JobRole', hue='Attrition')
plt.title('Attrition by Job Role')
plt.xlabel('Job Role')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()
